# %%
import numpy as np
import matplotlib.pyplot as plt

# 1. Определяем значения x
x = np.linspace(-10, 10, 400)  # Создаем 400 точек между -10 и 10

# 2. Вычисляем значения y
y = x**2

# 3. Создаем график
plt.figure(figsize=(8, 6)) # Настраиваем размер графика для лучшей видимости

# Рисуем график по точкам x и y
plt.plot(x, y)

# 4. Добавляем заголовок и подписи осей
plt.title('График функции y = x^2')
plt.xlabel('x')
plt.ylabel('y')

# 5. Добавляем сетку
plt.grid(True)

# 6. Отображаем график
plt.show()
